# %%
import streamlit as st
import requests
import pandas as pd
import altair as alt
import spacy
import re
from collections import Counter
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()
@st.cache_resource
def load_model():
    """Load the SpaCy German model."""
    return spacy.load("de_core_news_sm")

def extract_words_by_pos(text, nlp, pos):
    """
    Extract words of a specific part of speech from the text using SpaCy.
    """
    doc = nlp(text)
    words = [token.lemma_ for token in doc if token.pos_ == pos]
    return words
@st.cache_data
def load_text(url):
    """Download the text from the URL."""
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        st.error("Error fetching the text!")
        return ""

def process_text(text):
    """
    Process the text: remove punctuation, convert to lowercase,
    and count the frequency of each word (ignoring words with less than 2 letters).
    """
    # Use a regular expression to only capture words (alphabetic characters) of length 2 or more.
    words = re.findall(r'\b[a-z]{2,}\b', text.lower())
    return Counter(words)

def list_to_pandas(nouns):
    word = list(pd.Series(nouns).value_counts().index)
    number_times = list(pd.Series(nouns).value_counts().values)
    df = pd.DataFrame({"word":word, "frequency": number_times })
    return df
# Out:
# 2025-04-12 19:01:47.698 No runtime found, using MemoryCacheStorageManager

# %%
import logging

# Configure logging
logging.basicConfig(level=logging.ERROR) 

st.title("Word Frequency Visualizer")
st.write("""This Streamlit app reads a text from Project Gutenberg
         and shows the most popular words.""")

# URL to the text file on Project Gutenberg
url = "https://www.gutenberg.org/cache/epub/22367/pg22367.txt"
st.write(f"""This is the website: {url}""")
# Load and display basic info about the text
text = load_text(url)
if text:
    st.success("Text loaded successfully!")
else:
    st.stop()  # Stop the app if the text couldn't be loaded


# Load SpaCy German model
nlp = spacy.load("de_core_news_sm")

# Extract nouns, adjectives, and verbs
nouns = extract_words_by_pos(text, nlp, "NOUN")

adjectives = extract_words_by_pos(text, nlp, "ADJ")
verbs = extract_words_by_pos(text, nlp, "VERB")

# Display results and visualizations for nouns
st.write(f"### Extracted {len(nouns)} nouns.")

noun_counts = list_to_pandas(nouns)
adjective_counts = list_to_pandas(adjectives)
verb_counts = list_to_pandas(verbs)

st.dataframe(noun_counts)

noun_chart = alt.Chart(top_nouns).mark_bar().encode(
    x=alt.X("Frequency:Q", title="Frequency"),
    y=alt.Y("Noun:N", sort='-x', title="Noun"),
    tooltip=["Noun", "Frequency"]
).properties(
    width=600,
    height=400,
    title="Nouns in the Text"
)
st.altair_chart(noun_chart, use_container_width=True)

# Display results and visualizations for adjectives
st.write(f"### Extracted {len(adjectives)} adjectives.")
st.dataframe(adjective_counts)
st.write("### Top 20 Most Frequent Adjectives")
st.dataframe(noun_counts)

adj_chart = alt.Chart(top_adjectives).mark_bar().encode(
    x=alt.X("Frequency:Q", title="Frequency"),
    y=alt.Y("Adjective:N", sort='-x', title="Adjective"),
    tooltip=["Adjective", "Frequency"]
).properties(
    width=600,
    height=400,
    title="Adjectives in the Text"
)
st.altair_chart(adj_chart, use_container_width=True)

# Display results and visualizations for verbs
st.write(f"### Extracted {len(verbs)} verbs.")
st.dataframe(verb_counts)

verb_chart = alt.Chart(top_verbs).mark_bar().encode(
    x=alt.X("Frequency:Q", title="Frequency"),
    y=alt.Y("Verb:N", sort='-x', title="Verb"),
    tooltip=["Verb", "Frequency"]
).properties(
    width=600,
    height=400,
    title="Verbs in the Text"
)
st.altair_chart(verb_chart, use_container_width=True)
# Out:
# 2025-04-12 19:01:48.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:01:48.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\Rober\anaconda3\envs\pytorch-env\Lib\site-packages\altair\utils\core.py:264: UserWarning: I don't know how to infer vegalite type from 'empty'.  Defaulting to nominal.
#   warnings.warn(
# 2025-04-12 19:02:02.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\Rober\anaconda3\envs\pytorch-env\Lib\site-packages\altair\utils\core.py:264: UserWarning: I don't know how to infer vegalite type from 'empty'.  Defaulting to nominal.
#   warnings.warn(
# 2025-04-12 19:02:02.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\Rober\anaconda3\envs\pytorch-env\Lib\site-packages\altair\utils\core.py:264: UserWarning: I don't know how to infer vegalite type from 'empty'.  Defaulting to nominal.
#   warnings.warn(
# 2025-04-12 19:02:02.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 19:02:02.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Extract nouns, adjectives, and verbs
nouns = extract_words_by_pos(text, nlp, "NOUN")

adjectives = extract_words_by_pos(text, nlp, "ADJ")
verbs = extract_words_by_pos(text, nlp, "VERB")
print("holi")
# Display results and visualizations for nouns
st.write(f"### Extracted {len(nouns)} nouns.")
noun_counts = pd.DataFrame(pd.Series(nouns).value_counts(), columns=["word","Frequency"]).reset_index()
# Out:
# 2025-04-12 18:35:14.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 18:35:14.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 18:35:14.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 18:35:14.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# holi

# %%
#nouns

# %%
# Out:
#              word  frequency
# 0       Schwester        107
# 1           Vater        104
# 2          Mutter         91
# 3          Zimmer         79
# 4             Tür         62
# ...           ...        ...
# 1218     Bettrand          1
# 1219    erstaunen          1
# 1220  erschrecken          1
# 1221      Fremder          1
# 1222        Start          1
#
# [1223 rows x 2 columns]

# %%
# Out:
# array([107, 104,  91, ...,   1,   1,   1], dtype=int64)
